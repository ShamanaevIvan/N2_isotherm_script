# %%
from N2_adsorption_isotherm import Isotherm

# %%
a = Isotherm('../DATA73_X-Al2O3.083')

# %%
a.df_analysis_log
# Out:
#                      RELATIVE PRESSURE  PRESSURE (mmHg)  \
# DATE
# 2019-06-20 12:14:41                NaN              NaN
# 2019-06-20 13:40:41             0.0047            3.558
# 2019-06-20 13:57:41             0.0092            6.984
# 2019-06-20 14:06:41             0.0283           21.414
# 2019-06-20 14:15:41             0.0549           41.576
# 2019-06-20 14:16:41                NaN              NaN
# 2019-06-20 14:22:41             0.0724           54.886
# 2019-06-20 14:28:41             0.0983           74.455
# 2019-06-20 14:37:41             0.1467          111.191
# 2019-06-20 14:43:41             0.1973          149.493
# 2019-06-20 14:50:41             0.2475          187.514
# 2019-06-20 14:57:41             0.2978          225.632
# 2019-06-20 15:06:41             0.3874          293.552
# 2019-06-20 15:21:41             0.5212          394.918
# 2019-06-20 15:30:41             0.5506          417.145
# 2019-06-20 15:41:41             0.5928          449.118
# ...

# %%
a.plot_isotherm()
